# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('ggplot')

plt.rcParams['figure.figsize'] = [8, 8]

MAP='winter' # choose carefully, or color transitions will not appear smoooth
cm = plt.get_cmap(MAP)


df = pd.read_csv('dump.tsv', sep='\t', names=['v0','v1'])

plt.plot(df['v0'], df['v1'], '-', linewidth=0.4)
plt.title('Sensor data')
plt.show()

# %%
# !pip install pyserial
# Out:
# Requirement already satisfied: pyserial in ./venv/lib/python3.6/site-packages (3.4)
